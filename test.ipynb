# %%
import quantstats as qs
import yfinance as yf
import matplotlib.pyplot as plt

# %%
start = '2010-01-01'
end = '2012-01-01'
aapl = yf.download('AAPL', start=start, end=end)['Adj Close'].pct_change()
sp500 = yf.download('^GSPC', start=start, end=end)['Adj Close'].pct_change()
# sp500.index = results['returns'].index
qs.reports.full(aapl, benchmark = sp500, figsize=(8, 4))
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# <h4>Performance Metrics</h4>
#                            Benchmark    Strategy
# -------------------------  -----------  ----------
# Start Period               2010-01-06   2010-01-06
# End Period                 2011-12-30   2011-12-30
# Risk-Free Rate             0.0%         0.0%
# Time in Market             100.0%       100.0%
#
# Cumulative Return          10.65%       88.92%
# CAGR﹪                     3.59%        24.82%
#
# Sharpe                     0.35         1.34
# Prob. Sharpe Ratio         68.77%       97.06%
# Smart Sharpe               0.34         1.31
# Sortino                    0.48         2.02
# Smart Sortino              0.47         1.99
# Sortino/√2                 0.34         1.43
# Smart Sortino/√2           0.33         1.41
# Omega                      1.25         1.25
#
# Max Drawdown               -19.39%      -13.89%
# Longest DD Days            243          148
# Volatility (ann.)          20.82%       26.52%
# R^2                        0.47         0.47
# Information Ratio          0.09         0.09
# Calmar                     0.19         1.79
# Skew                       -0.35        0.08
# Kurtosis                   2.89         1.69
#
# Expected Daily %           0.02%        0.13%
# Expected Monthly %         0.42%        2.69%
# Expected Yearly %          5.19%        37.45%
# Kelly Criterion            -0.82%       4.95%
# Risk of Ruin               0.0%         0.0%
# Daily Value-at-Risk        -2.13%       -2.61%
# Expected Shortfall (cVaR)  -2.13%       -2.61%
#
# Max Consecutive Wins       6            10
# Max Consecutive Losses     7            7
# Gain/Pain Ratio            0.06         0.25
# Gain/Pain (1M)             0.35         2.34
#
# Payoff Ratio               0.78         0.92
# Profit Factor              1.06         1.25
# Common Sense Ratio         0.98         1.35
# CPC Index                  0.46         0.63
# Tail Ratio                 0.92         1.08
# Outlier Win Ratio          4.62         3.05
# Outlier Loss Ratio         3.94         3.23
#
# MTD                        0.85%        5.97%
# 3M                         8.38%        3.69%
# 6M                         -3.81%       21.24%
# YTD                        -0.0%        25.56%
# 1Y                         -0.17%       24.5%
# 3Y (ann.)                  3.59%        24.82%
# 5Y (ann.)                  3.59%        24.82%
# 10Y (ann.)                 3.59%        24.82%
# All-time (ann.)            3.59%        24.82%
#
# Best Day                   4.74%        7.69%
# Worst Day                  -6.66%       -5.59%
# Best Month                 10.77%       16.72%
# Worst Month                -8.2%        -10.41%
# Best Year                  10.66%       50.46%
# Worst Year                 -0.0%        25.56%
#
# Avg. Drawdown              -2.82%       -4.21%
# Avg. Drawdown Days         28           20
# Recovery Factor            0.75         5.08
# Ulcer Index                0.08         0.06
# Serenity Index             0.18         2.01
#
# Avg. Up Month              4.67%        6.92%
# Avg. Down Month            -4.05%       -3.3%
# Win Days %                 55.78%       54.38%
# Win Month %                50.0%        58.33%
# Win Quarter %              62.5%        87.5%
# Win Year %                 50.0%        100.0%
#
# Beta                       -            0.87
# Alpha                      -            0.29
# Correlation                -            68.56%
# Treynor Ratio              -            101.8%
# None
# <h4 style="margin-bottom:20px">Worst 5 Drawdowns</h4>
#         Start      Valley         End  Days  Max Drawdown  99% Max Drawdown
# 1  2011-10-19  2011-11-25  2011-12-30    73    -13.894932        -13.084968
# 2  2011-02-17  2011-06-20  2011-07-14   148    -13.166072        -11.158526
# 3  2010-04-26  2010-05-07  2010-06-16    52    -12.912180        -12.210613
# 4  2010-06-21  2010-08-24  2010-09-15    87    -12.456619        -12.328936
# 5  2011-07-27  2011-08-08  2011-09-16    52    -12.443914        -11.744886
# <h4>Strategy Visualization</h4>
